# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = "/content/drive/MyDrive/plant dataset/train"  # <-- Update this path

# Preprocess and load images
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 3364 images belonging to 4 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential([
    Input(shape=(224, 224, 3)),  # <--- Add this line
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(4, activation='softmax')  # Replace "4" with your class count
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Load validation data
val_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'  # Use the same generator but for validation split
)

# Verify validation data
print("Validation classes:", val_data.class_indices)
print("Validation samples:", val_data.samples)
# Out:
# Found 838 images belonging to 4 classes.
# Validation classes: {'Blight': 0, 'Common_Rust': 1, 'Gray_Leaf_Spot': 2, 'Healthy': 3}
# Validation samples: 838

# %%
# Train the model
history = model.fit(
    train_data,          # Training dataset
    epochs=10,           # Number of training cycles (adjust as needed)
    validation_data=val_data  # Validation dataset
)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-9fdf064ec11a> in <cell line: 0>()
#       1 # Train the model
# ----> 2 history = model.fit(
#       3     train_data,          # Training dataset
#       4     epochs=10,           # Number of training cycles (adjust as needed)
#       5     validation_data=val_data  # Validation dataset
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
# Save to Google Drive
model.save('/content/drive/MyDrive/plant dataset/plant_disease_model.h5')
print("Model saved! 🚀")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved! 🚀

# %%
# Check validation accuracy/loss
loss, accuracy = model.evaluate(val_data)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8515 - loss: 0.9460
# Validation Accuracy: 85.32%

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.legend()
plt.show()

# %%
test_image_path = "/content/drive/MyDrive/plant_dataset/test image.jpg"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()  # Upload the image from your computer
test_image_path = next(iter(uploaded))  # Get the uploaded file name
# Out:
#      <input type="file" id="files-8de439a0-a4d0-494f-b9f2-730420744afc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8de439a0-a4d0-494f-b9f2-730420744afc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Method 1: Upload directly to Colab (recommended)
uploaded = files.upload()  # Upload your test image
test_image_path = next(iter(uploaded))  # Auto-get path

# Method 2: OR use Google Drive path (if image is already uploaded)
# test_image_path = "/content/drive/MyDrive/plant_dataset/test_image.jpg"  # <- Verify path

try:
    # Load and preprocess image
    img = image.load_img(test_image_path, target_size=(224, 224))
    img = image.img_to_array(img) / 255.0
    img = np.expand_dims(img, axis=0)

    # Make prediction
    prediction = model.predict(img)
    predicted_class = np.argmax(prediction)
    confidence = np.max(prediction) * 100

    # Display result
    plt.imshow(image.load_img(test_image_path))
    plt.title(f"Predicted: {list(train_data.class_indices.keys())[predicted_class]}\nConfidence: {confidence:.2f}%")
    plt.axis('off')
    plt.show()

except FileNotFoundError:
    print(f"🔥 Error: File '{test_image_path}' not found!")
    print("1. Use the file upload button that appears when running files.upload()")
    print("2. Check Google Drive path matches EXACTLY (case-sensitive)")
    print("3. Ensure image is JPG/PNG format")
except Exception as e:
    print(f"❌ Error: {str(e)}")
# Out:
#      <input type="file" id="files-8fb8364a-bf86-4449-b31c-4d318cd15870" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fb8364a-bf86-4449-b31c-4d318cd15870">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Save as Keras .h5 file
model.save('/content/drive/MyDrive/plant_dataset/final_plant_disease_model.h5')

# Optional: Save as TensorFlow Lite (for mobile apps)
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('/content/drive/MyDrive/plant_dataset/model.tflite', 'wb') as f:
    f.write(tflite_model)
print("✅ Model saved in .h5 and .tflite formats!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved artifact at '/tmp/tmpmqfzl84a'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   134889464603728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966565520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966564944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966560336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966565904: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...

# %%
# !pip install gradio
import gradio as gr

def predict_image(img):
    img = img.resize((224, 224))
    img_array = np.array(img) / 255.0
    prediction = model.predict(np.expand_dims(img_array, axis=0))
    return list(train_data.class_indices.keys())[np.argmax(prediction)]

gr.Interface(
    fn=predict_image,
    inputs=gr.Image(type="pil"),
    outputs="label",
    title="🌿 Plant Disease Detector",
    description="Upload a leaf image to diagnose diseases!"
).launch(share=True)  # Generates a public link
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 65.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0d4667aa6842e9d9a6.gradio.live
#
# ...

# %%
# !pip install huggingface_hub
# !gradio deploy --title "Plant Disease Detector" --app-file "your_gradio_code.py" --space your-hf-username/plant-disease
# Out:
# ...
# Usage: gradio deploy [OPTIONS]
# Try 'gradio deploy --help' for help.
# ╭─ Error ──────────────────────────────────────────────────────────────────────────────────────────╮
# │ No such option: --space                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import tensorflow as tf

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

with open('/content/drive/MyDrive/plant_dataset/model.tflite', 'wb') as f:
    f.write(tflite_model)
print("✅ TFLite model saved!")
# Out:
# Saved artifact at '/tmp/tmpeoxvp5eu'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   134889464603728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966565520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966564944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966560336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966565904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966564176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966563600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134886966565712: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ TFLite model saved!
